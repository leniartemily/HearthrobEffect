# %%
# Import dependencies 
import pandas as pd

# %%
#importing Data
df = pd.read_csv('tracks.csv')

# %%
df
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %%
df[df['artists'] == "['Justin Bieber']"]
# Out:
#                             id                  name  popularity  duration_ms  \
# 82248   6eDApnV9Jdb1nYahOlbbUh              One Time          71       215867
# 82299   69ghzc538EQSVon2Gm3wrr  One Less Lonely Girl          69       229107
# 82372   0yIywEquxORnu1dR0WYsdN               Love Me          67       191573
# 83046   4nTjkWK590oBDcnIxTr1mI         Favorite Girl          58       256800
# 83249   0aPZbnkMoWJaJ5CNVLCj8S     That Should Be Me          70       232720
# ...                        ...                   ...         ...          ...
# 583293  0x7b1iQcJchYV55o1rUrs4               Love Me          49       191573
# 583312  4pYlyrBINcwbsBAemZ44CF  One Less Lonely Girl          47       229107
# 583320  6LtrSXoBzbTF3SxcJb1Fnm      Somebody To Love          49       220920
# 583333  1sZjOcNqpo7T6hDf1qFACC     That Should Be Me          46       232733
# 583341  0KDJBhhe2OYnnoJtbtXy1f               U Smile          45       196907
#
# ...

# %%
jb_df = df[df['artists'] == "['Justin Bieber']"]
jb_df.to_csv("Justin_Bieber.csv")
